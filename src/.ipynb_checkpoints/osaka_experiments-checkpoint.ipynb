# %% [markdown]
# # ICASSP Experiments
#
# Datasets : [OU-ISIR]
#
# **Data Variations**
# * Features = [Accelerometer Only, Accelerometer + Gyroscope]
# * Sequence Length = [1, 2, 3, 4]
# * Overlap = [no overlap, 0.25, 0.5, 0.75]
# * Train-Validation-Test split = [0.8, 0.1, 0.1]
#
# **Model Variations**
# * Dropout = [Yes, No]
# * BN = [Yes, No]
# * Weight Decay = [Yes, No]
# * Weight Decay + BN
# * Weight Decay + Dropout
#
# **Report:**
# * Mean EER
# * Std EER
# * Min EER
# * Max EER
#
# **Visualization**
# * Distance Vectors of Best and Worst combinations of all datasets stored in 200 ppt.

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !cp -r "/content/drive/My Drive/icmla2020/src" /content/
# !mv src/datasets.py datasets.py
# !mv src/models.py models.py
# !mv src/analyze.py analyze.py
# !ls
# Out:
# analyze.py  datasets.py  drive	models.py  sample_data	src

# %%
data_path = '../data/osaka'
results_path = '../results/'

# %%
import datasets, models, analyze
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.metrics import BinaryAccuracy
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import activations
# from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
# import nevergrad as ng
np.set_printoptions(precision=4)

# %%
def prepare_data(train_sps, val_sps, test_sps, max_cls, split, data, labels, indices_list, run_n):
    train_split = int(split[0] * max_cls)
    val_split = int(split[2] * max_cls)

    rand_indices = np.random.choice(range(max_cls), size=max_cls, replace=False)
    indices_list.append(rand_indices)
    print('Run #%d:'%run_n)
    
    all_data_rand, all_labels_rand = [data[x] for x in rand_indices], [labels[x] for x in rand_indices]
    b_data, b_labels = datasets.generate_batch(train_sps, all_data_rand[:train_split], all_labels_rand[:train_split])
    
    val_data, val_labels = datasets.generate_batch(val_sps, all_data_rand[train_split:train_split+val_split], all_labels_rand[train_split:train_split+val_split])
    ridx = np.random.choice(range(b_data[0].shape[0]), size=b_data[0].shape[0], replace=False)
    
    b_data_test, b_labels_test = datasets.generate_batch(test_sps, all_data_rand[train_split+val_split:], all_labels_rand[train_split+val_split:])

    l_input = b_data[0][ridx]
    r_input = b_data[1][ridx]
    b_labels = b_labels[ridx]

    # print(l_input[0].shape)

    l_input_val = val_data[0]
    r_input_val = val_data[1]

    l_input_test = b_data_test[0]
    r_input_test = b_data_test[1]
    return l_input, r_input, b_labels, l_input_val, r_input_val, val_labels, l_input_test, r_input_test, b_labels_test

# %%
def load_dataset(segLen, overlap, acc_only):
    data, labels = datasets.load_segment_osaka(data_path, 
                                            [0,744], 
                                            sample_rate=100,
                                            acc_only=acc_only,
                                            segment_time=segLen, 
                                            overlapped=overlap, 
                                            overlap=overlap, 
                                            downsample=True)
    return data, labels

# %%
def build_model1(input_shape, bn, reg):
    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import Conv1D, \
                                        MaxPooling1D, \
                                        AveragePooling1D, \
                                        Dense, Flatten, Dropout, \
                                        BatchNormalization, \
                                        GlobalMaxPooling1D, \
                                        GlobalAveragePooling1D, \
                                        Activation
    from tensorflow.keras import activations
    import tensorflow.keras.regularizers as regularizers

    model = Sequential()
    if reg:
        model.add(Conv1D(16, 3, strides=1, input_shape=input_shape, 
                        kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4),
                        bias_regularizer=regularizers.l2(1e-4)))
    else:
        model.add(Conv1D(16, 3, strides=1, input_shape=input_shape))
    if bn:
        model.add(BatchNormalization())
    model.add(Activation(activations.relu))
    model.add(MaxPooling1D(pool_size=2))
    if reg:
        model.add(Conv1D(64, 5, strides=2, 
                        kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4),
                        bias_regularizer=regularizers.l2(1e-4)))
    else:
        model.add(Conv1D(64, 5, strides=2))
    if bn:
        model.add(BatchNormalization())
    model.add(Activation(activations.relu))
    model.add(AveragePooling1D(pool_size=2))
    model.add(GlobalMaxPooling1D())
    return model

# %%
def build_model2(input_shape, bn, reg):
    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import Conv1D, \
                                        MaxPooling1D, \
                                        AveragePooling1D, \
                                        Dense, Flatten, Dropout, \
                                        BatchNormalization, \
                                        GlobalMaxPooling1D, \
                                        GlobalAveragePooling1D, \
                                        Activation
    from tensorflow.keras import activations
    import tensorflow.keras.regularizers as regularizers

    model = Sequential()
    if reg:
        model.add(Conv1D(16, 3, strides=1, activation='tanh', input_shape=input_shape, kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4),bias_regularizer=regularizers.l2(1e-4)))
        model.add(Conv1D(32, 3, strides=2, activation='relu', kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4),bias_regularizer=regularizers.l2(1e-4)))
    else:
        model.add(Conv1D(16, 3, strides=1, activation='tanh', input_shape=input_shape))
        model.add(Conv1D(32, 3, strides=2, activation='relu'))
    
    if bn:
        model.add(BatchNormalization())

    model.add(MaxPooling1D(pool_size=2))

    if reg:
        model.add(Conv1D(64, 5, strides=2, activation='tanh', kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4),bias_regularizer=regularizers.l2(1e-4)))
        model.add(Conv1D(128, 5, strides=3, activation='relu', kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4),bias_regularizer=regularizers.l2(1e-4)))
    else:
        model.add(Conv1D(64, 5, strides=2, activation='tanh'))
        model.add(Conv1D(128, 5, strides=3, activation='relu'))
    
    if bn:
        model.add(BatchNormalization())

    model.add(GlobalMaxPooling1D())
    return model

# %%
def build_model3(input_shape, bn, reg):
    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import Conv1D, \
                                        MaxPooling1D, \
                                        AveragePooling1D, \
                                        Dense, Flatten, Dropout, \
                                        BatchNormalization, \
                                        GlobalMaxPooling1D, \
                                        GlobalAveragePooling1D, \
                                        Activation
    from tensorflow.keras import activations
    import tensorflow.keras.regularizers as regularizers

    model = Sequential()
    model.add(Conv1D(64, 5, strides=3, padding='valid', activation='relu', input_shape=input_shape))
    if bn: model.add(BatchNormalization())
    model.add(Conv1D(128, 3, strides=2, padding='valid', activation='relu'))
    model.add(MaxPooling1D(pool_size=2, strides=2))
    model.add(Conv1D(128, 2, strides=1, padding='valid', activation='tanh'))
    model.add(MaxPooling1D(pool_size=2, strides=2))
    model.add(GlobalMaxPooling1D())
    return model

# %%
def build_model4(input_shape, bn, reg):
    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import Conv1D, \
                                        MaxPooling1D, \
                                        AveragePooling1D, \
                                        Dense, Flatten, Dropout, \
                                        BatchNormalization, \
                                        GlobalMaxPooling1D, \
                                        GlobalAveragePooling1D, \
                                        Activation
    from tensorflow.keras import activations
    import tensorflow.keras.regularizers as regularizers

    model = Sequential()
    if reg:
        model.add(Conv1D(32, 3, strides=1, input_shape=input_shape, 
                        kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4),
                        bias_regularizer=regularizers.l2(1e-4)))
    else:
        model.add(Conv1D(32, 3, strides=1, input_shape=input_shape))
    if bn:
        model.add(BatchNormalization())
    model.add(Activation(activations.relu))
    model.add(MaxPooling1D(pool_size=2))
    if reg:
        model.add(Conv1D(128, 5, strides=2, 
                        kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4),
                        bias_regularizer=regularizers.l2(1e-4)))
    else:
        model.add(Conv1D(128, 5, strides=2))
    if bn:
        model.add(BatchNormalization())
    model.add(Activation(activations.relu))
    model.add(AveragePooling1D(pool_size=2))
    model.add(GlobalMaxPooling1D())
    return model

# %%
def build_model5(input_shape, bn, reg):
    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import Conv1D, \
                                        MaxPooling1D, \
                                        AveragePooling1D, \
                                        Dense, Flatten, Dropout, \
                                        BatchNormalization, \
                                        GlobalMaxPooling1D, \
                                        GlobalAveragePooling1D, \
                                        Activation
    from tensorflow.keras import activations
    import tensorflow.keras.regularizers as regularizers

    model = Sequential()
    if reg:
        model.add(Conv1D(64, 3, strides=1, input_shape=input_shape, 
                        kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4),
                        bias_regularizer=regularizers.l2(1e-4)))
    else:
        model.add(Conv1D(64, 3, strides=1, input_shape=input_shape))
    if bn:
        model.add(BatchNormalization())
    model.add(Activation(activations.relu))
    model.add(MaxPooling1D(pool_size=2))
    if reg:
        model.add(Conv1D(256, 5, strides=2, 
                        kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4),
                        bias_regularizer=regularizers.l2(1e-4)))
    else:
        model.add(Conv1D(256, 5, strides=2))
    if bn:
        model.add(BatchNormalization())
    model.add(Activation(activations.relu))
    model.add(AveragePooling1D(pool_size=2))
    model.add(GlobalMaxPooling1D())
    return model

# %%
acc_only_list    = [False, True]
segLen_list      = [1, 2]
overlap_list     = [0, 0.25, 0.5, 0.75]
# models_list      = [build_model1, build_model2, build_model3]
models_list      = [build_model4, build_model5]
bn_list          = [True, False]
reg_list         = [True, False]

# Configurations
train_sps       = 50
val_sps         = 20
test_sps        = 20
max_cls         = 744
split           = [0.8, 0.1, 0.1]
output_dropout  = 0.1
runs            = 15
np.set_printoptions(precision=4)

# %%
data, labels = load_dataset(2, 0.75, acc_only=False)

# Results of this configuration/experiment
EERs = np.array([np.zeros(runs) for _ in range(3*2*2)])

for run_n in range(runs):
    l_input, r_input, b_labels, l_input_val, r_input_val, val_labels, l_input_test, r_input_test, b_labels_test = prepare_data(train_sps,
                                                                                                                                val_sps,
                                                                                                                                test_sps,
                                                                                                                                max_cls,
                                                                                                                                split,
                                                                                                                                data,
                                                                                                                                labels,
                                                                                                                                [],
                                                                                                                                run_n)
    adam = Adam(learning_rate=0.001)
    earlystop = EarlyStopping(monitor='val_accuracy', patience=5)
    for bn in bn_list:
        for reg in reg_list:
            for model_index, build_cnn in enumerate(models_list):
                cnn = build_cnn(l_input[0].shape, bn, reg)
                siamese = models.build_siamese(l_input[0].shape, cnn, output_dropout)
                siamese.compile(loss='binary_crossentropy', optimizer=adam, metrics=[BinaryAccuracy(name='accuracy')])
                if run_n == 0: 
                    cnn.summary()
                hist = siamese.fit([l_input, r_input], 
                                    b_labels, 
                                    shuffle=True,
                                    batch_size=64,
                                    epochs=100,
                                    callbacks=[earlystop],
                                    validation_data=([l_input_val, r_input_val], val_labels),
                                    verbose=2
                                    )
                FRR, FAR, EER, EER_th = analyze.ROC(siamese, [l_input_test, r_input_test], b_labels_test)
                EERs[4 * model_index + 2*bn + reg , run_n] = EER
                np.save(results_path + 'osaka_filters_eers.npy', EERs)
# Out:
# Run #0:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 98, 32)            608
# _________________________________________________________________
# batch_normalization (BatchNo (None, 98, 32)            128
# _________________________________________________________________
# activation (Activation)      (None, 98, 32)            0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 49, 32)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 23, 128)           20608
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 23, 128)           512
# _________________________________________________________________
# activation_1 (Activation)    (None, 23, 128)           0
# _________________________________________________________________
# average_pooling1d (AveragePo (None, 11, 128)           0
# _________________________________________________________________
# global_max_pooling1d (Global (None, 128)               0
# =================================================================
# Total params: 21,856
# Trainable params: 21,536
# Non-trainable params: 320
# _________________________________________________________________
# Epoch 1/100
# 930/930 - 20s - loss: 0.2546 - accuracy: 0.9138 - val_loss: 0.1738 - val_accuracy: 0.9324
# Epoch 2/100
# 930/930 - 19s - loss: 0.1307 - accuracy: 0.9630 - val_loss: 0.1617 - val_accuracy: 0.9449
# Epoch 3/100
# 930/930 - 18s - loss: 0.1021 - accuracy: 0.9734 - val_loss: 0.1545 - val_accuracy: 0.9524
# Epoch 4/100
# 930/930 - 18s - loss: 0.0864 - accuracy: 0.9793 - val_loss: 0.1567 - val_accuracy: 0.9503
# Epoch 5/100
# 930/930 - 18s - loss: 0.0776 - accuracy: 0.9821 - val_loss: 0.1387 - val_accuracy: 0.9601
# Epoch 6/100
# 930/930 - 18s - loss: 0.0718 - accuracy: 0.9844 - val_loss: 0.1377 - val_accuracy: 0.9551
# Epoch 7/100
# 930/930 - 18s - loss: 0.0684 - accuracy: 0.9860 - val_loss: 0.1479 - val_accuracy: 0.9547
# Epoch 8/100
# 930/930 - 18s - loss: 0.0675 - accuracy: 0.9862 - val_loss: 0.1553 - val_accuracy: 0.9497
# Epoch 9/100
# 930/930 - 19s - loss: 0.0643 - accuracy: 0.9877 - val_loss: 0.1537 - val_accuracy: 0.9598
# Epoch 10/100
# 930/930 - 18s - loss: 0.0591 - accuracy: 0.9895 - val_loss: 0.1342 - val_accuracy: 0.9628
# Epoch 11/100
# 930/930 - 18s - loss: 0.0609 - accuracy: 0.9889 - val_loss: 0.1516 - val_accuracy: 0.9581
# Epoch 12/100
# 930/930 - 18s - loss: 0.0584 - accuracy: 0.9899 - val_loss: 0.1799 - val_accuracy: 0.9547
# Epoch 13/100
# 930/930 - 18s - loss: 0.0593 - accuracy: 0.9901 - val_loss: 0.1544 - val_accuracy: 0.9564
# Epoch 14/100
# 930/930 - 18s - loss: 0.0558 - accuracy: 0.9917 - val_loss: 0.1544 - val_accuracy: 0.9608
# Epoch 15/100
# 930/930 - 18s - loss: 0.0571 - accuracy: 0.9905 - val_loss: 0.1598 - val_accuracy: 0.9584
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2 (Conv1D)            (None, 98, 64)            1216
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 98, 64)            256
# _________________________________________________________________
# activation_2 (Activation)    (None, 98, 64)            0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 49, 64)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 23, 256)           82176
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 23, 256)           1024
# _________________________________________________________________
# activation_3 (Activation)    (None, 23, 256)           0
# _________________________________________________________________
# average_pooling1d_1 (Average (None, 11, 256)           0
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 256)               0
# =================================================================
# Total params: 84,672
# Trainable params: 84,032
# Non-trainable params: 640
# _________________________________________________________________
# Epoch 1/100
# 930/930 - 47s - loss: 0.2095 - accuracy: 0.9475 - val_loss: 0.1862 - val_accuracy: 0.9500
# Epoch 2/100
# 930/930 - 49s - loss: 0.1241 - accuracy: 0.9804 - val_loss: 0.1624 - val_accuracy: 0.9605
# Epoch 3/100
# 930/930 - 49s - loss: 0.1062 - accuracy: 0.9851 - val_loss: 0.1663 - val_accuracy: 0.9588
# Epoch 4/100
# 930/930 - 49s - loss: 0.0983 - accuracy: 0.9870 - val_loss: 0.1442 - val_accuracy: 0.9686
# Epoch 5/100
# 930/930 - 51s - loss: 0.0896 - accuracy: 0.9900 - val_loss: 0.1896 - val_accuracy: 0.9520
# Epoch 6/100
# 930/930 - 51s - loss: 0.0935 - accuracy: 0.9886 - val_loss: 0.1764 - val_accuracy: 0.9547
# Epoch 7/100
# 930/930 - 47s - loss: 0.0871 - accuracy: 0.9912 - val_loss: 0.1791 - val_accuracy: 0.9591
# Epoch 8/100
# 930/930 - 49s - loss: 0.0868 - accuracy: 0.9902 - val_loss: 0.1678 - val_accuracy: 0.9652
# Epoch 9/100
# 930/930 - 48s - loss: 0.0858 - accuracy: 0.9907 - val_loss: 0.1790 - val_accuracy: 0.9584
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_4 (Conv1D)            (None, 98, 32)            608
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 98, 32)            128
# _________________________________________________________________
# activation_4 (Activation)    (None, 98, 32)            0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 49, 32)            0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 23, 128)           20608
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 23, 128)           512
# _________________________________________________________________
# activation_5 (Activation)    (None, 23, 128)           0
# _________________________________________________________________
# average_pooling1d_2 (Average (None, 11, 128)           0
# _________________________________________________________________
# global_max_pooling1d_2 (Glob (None, 128)               0
# =================================================================
# Total params: 21,856
# Trainable params: 21,536
# Non-trainable params: 320
# _________________________________________________________________
# Epoch 1/100
# 930/930 - 18s - loss: 0.1765 - accuracy: 0.9358 - val_loss: 0.1541 - val_accuracy: 0.9466
# Epoch 2/100
# 930/930 - 18s - loss: 0.0836 - accuracy: 0.9734 - val_loss: 0.1259 - val_accuracy: 0.9490
# Epoch 3/100
# 930/930 - 18s - loss: 0.0585 - accuracy: 0.9819 - val_loss: 0.1369 - val_accuracy: 0.9510
# Epoch 4/100
# 930/930 - 18s - loss: 0.0482 - accuracy: 0.9847 - val_loss: 0.1275 - val_accuracy: 0.9514
# Epoch 5/100
# 930/930 - 18s - loss: 0.0401 - accuracy: 0.9877 - val_loss: 0.1268 - val_accuracy: 0.9584
# Epoch 6/100
# 930/930 - 18s - loss: 0.0348 - accuracy: 0.9889 - val_loss: 0.1199 - val_accuracy: 0.9554
# Epoch 7/100
# 930/930 - 18s - loss: 0.0300 - accuracy: 0.9907 - val_loss: 0.1348 - val_accuracy: 0.9557
# Epoch 8/100
# 930/930 - 18s - loss: 0.0281 - accuracy: 0.9912 - val_loss: 0.1305 - val_accuracy: 0.9507
# Epoch 9/100
# 930/930 - 19s - loss: 0.0244 - accuracy: 0.9924 - val_loss: 0.1143 - val_accuracy: 0.9507
# Epoch 10/100
# 930/930 - 19s - loss: 0.0223 - accuracy: 0.9929 - val_loss: 0.1211 - val_accuracy: 0.9554
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_6 (Conv1D)            (None, 98, 64)            1216
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 98, 64)            256
# _________________________________________________________________
# activation_6 (Activation)    (None, 98, 64)            0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 49, 64)            0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 23, 256)           82176
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 23, 256)           1024
# _________________________________________________________________
# activation_7 (Activation)    (None, 23, 256)           0
# _________________________________________________________________
# average_pooling1d_3 (Average (None, 11, 256)           0
# _________________________________________________________________
# global_max_pooling1d_3 (Glob (None, 256)               0
# =================================================================
# Total params: 84,672
# Trainable params: 84,032
# Non-trainable params: 640
# _________________________________________________________________
# Epoch 1/100
# 930/930 - 50s - loss: 0.1506 - accuracy: 0.9473 - val_loss: 0.1241 - val_accuracy: 0.9507
# Epoch 2/100
# 930/930 - 51s - loss: 0.0590 - accuracy: 0.9816 - val_loss: 0.1193 - val_accuracy: 0.9493
# Epoch 3/100
# 930/930 - 49s - loss: 0.0380 - accuracy: 0.9884 - val_loss: 0.0965 - val_accuracy: 0.9622
# Epoch 4/100
# 930/930 - 50s - loss: 0.0261 - accuracy: 0.9928 - val_loss: 0.1144 - val_accuracy: 0.9598
# Epoch 5/100
# 930/930 - 50s - loss: 0.0208 - accuracy: 0.9941 - val_loss: 0.1464 - val_accuracy: 0.9517
# Epoch 6/100
# 930/930 - 50s - loss: 0.0203 - accuracy: 0.9940 - val_loss: 0.1550 - val_accuracy: 0.9547
# Epoch 7/100
# 930/930 - 51s - loss: 0.0154 - accuracy: 0.9955 - val_loss: 0.1581 - val_accuracy: 0.9568
# Epoch 8/100
# 930/930 - 49s - loss: 0.0149 - accuracy: 0.9954 - val_loss: 0.1431 - val_accuracy: 0.9561
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_8 (Conv1D)            (None, 98, 32)            608
# _________________________________________________________________
# activation_8 (Activation)    (None, 98, 32)            0
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 49, 32)            0
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 23, 128)           20608
# _________________________________________________________________
# activation_9 (Activation)    (None, 23, 128)           0
# _________________________________________________________________
# average_pooling1d_4 (Average (None, 11, 128)           0
# _________________________________________________________________
# global_max_pooling1d_4 (Glob (None, 128)               0
# =================================================================
# Total params: 21,216
# Trainable params: 21,216
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 930/930 - 16s - loss: 0.2563 - accuracy: 0.9091 - val_loss: 0.2146 - val_accuracy: 0.9247
# Epoch 2/100
# 930/930 - 15s - loss: 0.1463 - accuracy: 0.9639 - val_loss: 0.1864 - val_accuracy: 0.9382
# Epoch 3/100
# 930/930 - 16s - loss: 0.1203 - accuracy: 0.9741 - val_loss: 0.1869 - val_accuracy: 0.9426
# Epoch 4/100
# 930/930 - 16s - loss: 0.1043 - accuracy: 0.9794 - val_loss: 0.1801 - val_accuracy: 0.9459
# Epoch 5/100
# 930/930 - 16s - loss: 0.0937 - accuracy: 0.9834 - val_loss: 0.1842 - val_accuracy: 0.9402
# Epoch 6/100
# 930/930 - 16s - loss: 0.0876 - accuracy: 0.9849 - val_loss: 0.1902 - val_accuracy: 0.9429
# Epoch 7/100
# 930/930 - 16s - loss: 0.0819 - accuracy: 0.9869 - val_loss: 0.1758 - val_accuracy: 0.9470
# Epoch 8/100
# 930/930 - 15s - loss: 0.0776 - accuracy: 0.9882 - val_loss: 0.1799 - val_accuracy: 0.9416
# Epoch 9/100
# 930/930 - 15s - loss: 0.0729 - accuracy: 0.9893 - val_loss: 0.1753 - val_accuracy: 0.9537
# Epoch 10/100
# 930/930 - 15s - loss: 0.0716 - accuracy: 0.9896 - val_loss: 0.1941 - val_accuracy: 0.9459
# Epoch 11/100
# 930/930 - 15s - loss: 0.0697 - accuracy: 0.9903 - val_loss: 0.1814 - val_accuracy: 0.9480
# Epoch 12/100
# 930/930 - 15s - loss: 0.0670 - accuracy: 0.9912 - val_loss: 0.1740 - val_accuracy: 0.9507
# Epoch 13/100
# 930/930 - 15s - loss: 0.0658 - accuracy: 0.9910 - val_loss: 0.1639 - val_accuracy: 0.9524
# Epoch 14/100
# 930/930 - 16s - loss: 0.0641 - accuracy: 0.9918 - val_loss: 0.1890 - val_accuracy: 0.9490
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_10 (Conv1D)           (None, 98, 64)            1216
# _________________________________________________________________
# activation_10 (Activation)   (None, 98, 64)            0
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 49, 64)            0
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 23, 256)           82176
# _________________________________________________________________
# activation_11 (Activation)   (None, 23, 256)           0
# _________________________________________________________________
# average_pooling1d_5 (Average (None, 11, 256)           0
# _________________________________________________________________
# global_max_pooling1d_5 (Glob (None, 256)               0
# =================================================================
# Total params: 83,392
# Trainable params: 83,392
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 930/930 - 44s - loss: 0.2320 - accuracy: 0.9382 - val_loss: 0.2279 - val_accuracy: 0.9314
# Epoch 2/100
# 930/930 - 44s - loss: 0.1485 - accuracy: 0.9744 - val_loss: 0.2127 - val_accuracy: 0.9402
# Epoch 3/100
# 930/930 - 45s - loss: 0.1254 - accuracy: 0.9820 - val_loss: 0.2221 - val_accuracy: 0.9385
# Epoch 4/100
# 930/930 - 45s - loss: 0.1114 - accuracy: 0.9859 - val_loss: 0.2220 - val_accuracy: 0.9439
# Epoch 5/100
# 930/930 - 45s - loss: 0.1045 - accuracy: 0.9873 - val_loss: 0.2083 - val_accuracy: 0.9419
# Epoch 6/100
# 930/930 - 46s - loss: 0.0981 - accuracy: 0.9888 - val_loss: 0.1868 - val_accuracy: 0.9551
# Epoch 7/100
# 930/930 - 43s - loss: 0.0925 - accuracy: 0.9901 - val_loss: 0.1985 - val_accuracy: 0.9524
# Epoch 8/100
# 930/930 - 42s - loss: 0.0894 - accuracy: 0.9904 - val_loss: 0.1827 - val_accuracy: 0.9537
# Epoch 9/100
# 930/930 - 42s - loss: 0.0861 - accuracy: 0.9912 - val_loss: 0.1994 - val_accuracy: 0.9490
# Epoch 10/100
# 930/930 - 42s - loss: 0.0833 - accuracy: 0.9915 - val_loss: 0.1738 - val_accuracy: 0.9578
# Epoch 11/100
# 930/930 - 44s - loss: 0.0803 - accuracy: 0.9922 - val_loss: 0.1974 - val_accuracy: 0.9476
# Epoch 12/100
# 930/930 - 42s - loss: 0.0762 - accuracy: 0.9930 - val_loss: 0.1768 - val_accuracy: 0.9561
# Epoch 13/100
# 930/930 - 42s - loss: 0.0776 - accuracy: 0.9923 - val_loss: 0.1523 - val_accuracy: 0.9628
# Epoch 14/100
# 930/930 - 43s - loss: 0.0738 - accuracy: 0.9932 - val_loss: 0.1757 - val_accuracy: 0.9564
# Epoch 15/100
# 930/930 - 43s - loss: 0.0709 - accuracy: 0.9937 - val_loss: 0.1674 - val_accuracy: 0.9598
# Epoch 16/100
# 930/930 - 43s - loss: 0.0707 - accuracy: 0.9936 - val_loss: 0.1699 - val_accuracy: 0.9595
# Epoch 17/100
# 930/930 - 43s - loss: 0.0673 - accuracy: 0.9939 - val_loss: 0.1677 - val_accuracy: 0.9591
# Epoch 18/100
# 930/930 - 42s - loss: 0.0650 - accuracy: 0.9944 - val_loss: 0.1793 - val_accuracy: 0.9524
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_12 (Conv1D)           (None, 98, 32)            608
# _________________________________________________________________
# activation_12 (Activation)   (None, 98, 32)            0
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 49, 32)            0
# _________________________________________________________________
# conv1d_13 (Conv1D)           (None, 23, 128)           20608
# _________________________________________________________________
# activation_13 (Activation)   (None, 23, 128)           0
# _________________________________________________________________
# average_pooling1d_6 (Average (None, 11, 128)           0
# _________________________________________________________________
# global_max_pooling1d_6 (Glob (None, 128)               0
# =================================================================
# Total params: 21,216
# Trainable params: 21,216
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 930/930 - 15s - loss: 0.2105 - accuracy: 0.9168 - val_loss: 0.2075 - val_accuracy: 0.9145
# Epoch 2/100
# 930/930 - 15s - loss: 0.1122 - accuracy: 0.9621 - val_loss: 0.1948 - val_accuracy: 0.9250
# Epoch 3/100
# 930/930 - 15s - loss: 0.0869 - accuracy: 0.9713 - val_loss: 0.2252 - val_accuracy: 0.9186
# Epoch 4/100
# 930/930 - 16s - loss: 0.0704 - accuracy: 0.9766 - val_loss: 0.1628 - val_accuracy: 0.9351
# Epoch 5/100
# 930/930 - 15s - loss: 0.0605 - accuracy: 0.9804 - val_loss: 0.1699 - val_accuracy: 0.9338
# Epoch 6/100
# 930/930 - 15s - loss: 0.0523 - accuracy: 0.9827 - val_loss: 0.1774 - val_accuracy: 0.9297
# Epoch 7/100
# 930/930 - 15s - loss: 0.0464 - accuracy: 0.9852 - val_loss: 0.1482 - val_accuracy: 0.9368
# Epoch 8/100
# 930/930 - 16s - loss: 0.0408 - accuracy: 0.9867 - val_loss: 0.1543 - val_accuracy: 0.9412
# Epoch 9/100
# 930/930 - 16s - loss: 0.0362 - accuracy: 0.9888 - val_loss: 0.1739 - val_accuracy: 0.9385
# Epoch 10/100
# 930/930 - 16s - loss: 0.0344 - accuracy: 0.9884 - val_loss: 0.1522 - val_accuracy: 0.9463
# Epoch 11/100
# 930/930 - 16s - loss: 0.0302 - accuracy: 0.9905 - val_loss: 0.1653 - val_accuracy: 0.9405
# Epoch 12/100
# 930/930 - 15s - loss: 0.0281 - accuracy: 0.9911 - val_loss: 0.1684 - val_accuracy: 0.9432
# Epoch 13/100
# 930/930 - 15s - loss: 0.0253 - accuracy: 0.9922 - val_loss: 0.1590 - val_accuracy: 0.9476
# Epoch 14/100
# 930/930 - 15s - loss: 0.0261 - accuracy: 0.9912 - val_loss: 0.1611 - val_accuracy: 0.9443
# Epoch 15/100
# 930/930 - 15s - loss: 0.0233 - accuracy: 0.9922 - val_loss: 0.1686 - val_accuracy: 0.9520
# Epoch 16/100
# 930/930 - 15s - loss: 0.0218 - accuracy: 0.9928 - val_loss: 0.1475 - val_accuracy: 0.9497
# Epoch 17/100
# 930/930 - 15s - loss: 0.0198 - accuracy: 0.9938 - val_loss: 0.1667 - val_accuracy: 0.9483
# Epoch 18/100
# 930/930 - 15s - loss: 0.0189 - accuracy: 0.9941 - val_loss: 0.1819 - val_accuracy: 0.9446
# Epoch 19/100
# 930/930 - 17s - loss: 0.0183 - accuracy: 0.9941 - val_loss: 0.1708 - val_accuracy: 0.9426
# Epoch 20/100
# 930/930 - 15s - loss: 0.0180 - accuracy: 0.9944 - val_loss: 0.1702 - val_accuracy: 0.9463
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_14 (Conv1D)           (None, 98, 64)            1216
# _________________________________________________________________
# activation_14 (Activation)   (None, 98, 64)            0
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 49, 64)            0
# _________________________________________________________________
# conv1d_15 (Conv1D)           (None, 23, 256)           82176
# _________________________________________________________________
# activation_15 (Activation)   (None, 23, 256)           0
# _________________________________________________________________
# average_pooling1d_7 (Average (None, 11, 256)           0
# _________________________________________________________________
# global_max_pooling1d_7 (Glob (None, 256)               0
# =================================================================
# Total params: 83,392
# Trainable params: 83,392
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 930/930 - 40s - loss: 0.1663 - accuracy: 0.9362 - val_loss: 0.1730 - val_accuracy: 0.9399
# Epoch 2/100
# 930/930 - 41s - loss: 0.0720 - accuracy: 0.9766 - val_loss: 0.1481 - val_accuracy: 0.9470
# Epoch 3/100
# 930/930 - 41s - loss: 0.0483 - accuracy: 0.9845 - val_loss: 0.1634 - val_accuracy: 0.9476
# Epoch 4/100
# 930/930 - 40s - loss: 0.0350 - accuracy: 0.9889 - val_loss: 0.1875 - val_accuracy: 0.9429
# Epoch 5/100
# 930/930 - 44s - loss: 0.0289 - accuracy: 0.9910 - val_loss: 0.1581 - val_accuracy: 0.9493
# Epoch 6/100
# 930/930 - 43s - loss: 0.0239 - accuracy: 0.9926 - val_loss: 0.1341 - val_accuracy: 0.9524
# Epoch 7/100
# 930/930 - 43s - loss: 0.0199 - accuracy: 0.9936 - val_loss: 0.1618 - val_accuracy: 0.9507
# Epoch 8/100
# 930/930 - 43s - loss: 0.0180 - accuracy: 0.9944 - val_loss: 0.1452 - val_accuracy: 0.9578
# Epoch 9/100
# 930/930 - 44s - loss: 0.0157 - accuracy: 0.9950 - val_loss: 0.1376 - val_accuracy: 0.9591
# Epoch 10/100
# 930/930 - 43s - loss: 0.0138 - accuracy: 0.9958 - val_loss: 0.2345 - val_accuracy: 0.9378
# Epoch 11/100
# 930/930 - 40s - loss: 0.0127 - accuracy: 0.9958 - val_loss: 0.2121 - val_accuracy: 0.9439
# Epoch 12/100
# 930/930 - 41s - loss: 0.0119 - accuracy: 0.9962 - val_loss: 0.1556 - val_accuracy: 0.9551
# Epoch 13/100
# 930/930 - 42s - loss: 0.0106 - accuracy: 0.9966 - val_loss: 0.1961 - val_accuracy: 0.9456
# Epoch 14/100
# 930/930 - 41s - loss: 0.0108 - accuracy: 0.9966 - val_loss: 0.1827 - val_accuracy: 0.9530
# Run #1:
# Epoch 1/100
# 930/930 - 20s - loss: 0.2603 - accuracy: 0.9098 - val_loss: 0.1598 - val_accuracy: 0.9480
# Epoch 2/100
# 930/930 - 19s - loss: 0.1336 - accuracy: 0.9620 - val_loss: 0.1364 - val_accuracy: 0.9530
# Epoch 3/100
# 930/930 - 18s - loss: 0.1030 - accuracy: 0.9721 - val_loss: 0.1417 - val_accuracy: 0.9547
# Epoch 4/100
# 930/930 - 18s - loss: 0.0857 - accuracy: 0.9791 - val_loss: 0.1259 - val_accuracy: 0.9642
# Epoch 5/100
# 930/930 - 18s - loss: 0.0761 - accuracy: 0.9827 - val_loss: 0.1359 - val_accuracy: 0.9564
# Epoch 6/100
# 930/930 - 18s - loss: 0.0707 - accuracy: 0.9840 - val_loss: 0.1303 - val_accuracy: 0.9588
# Epoch 7/100
# 930/930 - 19s - loss: 0.0692 - accuracy: 0.9857 - val_loss: 0.1357 - val_accuracy: 0.9591
# Epoch 8/100
# 930/930 - 19s - loss: 0.0634 - accuracy: 0.9873 - val_loss: 0.1321 - val_accuracy: 0.9628
# Epoch 9/100
# 930/930 - 18s - loss: 0.0629 - accuracy: 0.9879 - val_loss: 0.1360 - val_accuracy: 0.9625
# Epoch 1/100
# 930/930 - 48s - loss: 0.2099 - accuracy: 0.9476 - val_loss: 0.1595 - val_accuracy: 0.9659
# Epoch 2/100
# 930/930 - 48s - loss: 0.1237 - accuracy: 0.9803 - val_loss: 0.1387 - val_accuracy: 0.9723
# Epoch 3/100
# 930/930 - 48s - loss: 0.1034 - accuracy: 0.9864 - val_loss: 0.1397 - val_accuracy: 0.9716
# Epoch 4/100
# 930/930 - 48s - loss: 0.0971 - accuracy: 0.9882 - val_loss: 0.1455 - val_accuracy: 0.9689
# Epoch 5/100
# 930/930 - 48s - loss: 0.0940 - accuracy: 0.9887 - val_loss: 0.1330 - val_accuracy: 0.9764
# Epoch 6/100
# 930/930 - 48s - loss: 0.0897 - accuracy: 0.9897 - val_loss: 0.1569 - val_accuracy: 0.9669
# Epoch 7/100
# 930/930 - 47s - loss: 0.0870 - accuracy: 0.9904 - val_loss: 0.1697 - val_accuracy: 0.9662
# Epoch 8/100
# 930/930 - 48s - loss: 0.0850 - accuracy: 0.9911 - val_loss: 0.1348 - val_accuracy: 0.9740
# Epoch 9/100
# 930/930 - 49s - loss: 0.0862 - accuracy: 0.9908 - val_loss: 0.1541 - val_accuracy: 0.9666
# Epoch 10/100
# 930/930 - 51s - loss: 0.0828 - accuracy: 0.9919 - val_loss: 0.1458 - val_accuracy: 0.9720
# Epoch 1/100
# 930/930 - 20s - loss: 0.1905 - accuracy: 0.9311 - val_loss: 0.1298 - val_accuracy: 0.9537
# Epoch 2/100
# 930/930 - 20s - loss: 0.0919 - accuracy: 0.9696 - val_loss: 0.1067 - val_accuracy: 0.9635
# Epoch 3/100
# 930/930 - 20s - loss: 0.0642 - accuracy: 0.9797 - val_loss: 0.1065 - val_accuracy: 0.9605
# Epoch 4/100
# 930/930 - 21s - loss: 0.0524 - accuracy: 0.9834 - val_loss: 0.0894 - val_accuracy: 0.9682
# Epoch 5/100
# 930/930 - 19s - loss: 0.0427 - accuracy: 0.9860 - val_loss: 0.0933 - val_accuracy: 0.9689
# Epoch 6/100
# 930/930 - 18s - loss: 0.0388 - accuracy: 0.9878 - val_loss: 0.1076 - val_accuracy: 0.9649
# Epoch 7/100
# 930/930 - 19s - loss: 0.0341 - accuracy: 0.9888 - val_loss: 0.1021 - val_accuracy: 0.9625
# Epoch 8/100
# 930/930 - 19s - loss: 0.0294 - accuracy: 0.9908 - val_loss: 0.1066 - val_accuracy: 0.9652
# Epoch 9/100
# 930/930 - 18s - loss: 0.0263 - accuracy: 0.9917 - val_loss: 0.1078 - val_accuracy: 0.9696
# Epoch 10/100
# 930/930 - 19s - loss: 0.0241 - accuracy: 0.9927 - val_loss: 0.1046 - val_accuracy: 0.9736
# Epoch 11/100
# 930/930 - 18s - loss: 0.0235 - accuracy: 0.9926 - val_loss: 0.1068 - val_accuracy: 0.9713
# Epoch 12/100
# 930/930 - 18s - loss: 0.0221 - accuracy: 0.9929 - val_loss: 0.1080 - val_accuracy: 0.9693
# Epoch 13/100
# 930/930 - 19s - loss: 0.0202 - accuracy: 0.9933 - val_loss: 0.1315 - val_accuracy: 0.9669
# Epoch 14/100
# 930/930 - 18s - loss: 0.0196 - accuracy: 0.9938 - val_loss: 0.1078 - val_accuracy: 0.9696
# Epoch 15/100
# 930/930 - 18s - loss: 0.0179 - accuracy: 0.9942 - val_loss: 0.1143 - val_accuracy: 0.9723
# Epoch 1/100
# 930/930 - 48s - loss: 0.1437 - accuracy: 0.9492 - val_loss: 0.1009 - val_accuracy: 0.9645
# Epoch 2/100
# 930/930 - 50s - loss: 0.0555 - accuracy: 0.9832 - val_loss: 0.0907 - val_accuracy: 0.9723
# Epoch 3/100
# 930/930 - 50s - loss: 0.0363 - accuracy: 0.9895 - val_loss: 0.0891 - val_accuracy: 0.9686
# Epoch 4/100
# 930/930 - 50s - loss: 0.0269 - accuracy: 0.9923 - val_loss: 0.1039 - val_accuracy: 0.9652
# Epoch 5/100
# 930/930 - 51s - loss: 0.0213 - accuracy: 0.9937 - val_loss: 0.1034 - val_accuracy: 0.9659
# Epoch 6/100
# 930/930 - 53s - loss: 0.0167 - accuracy: 0.9954 - val_loss: 0.1079 - val_accuracy: 0.9662
# Epoch 7/100
# 930/930 - 53s - loss: 0.0153 - accuracy: 0.9955 - val_loss: 0.1044 - val_accuracy: 0.9615
# Epoch 1/100
# 930/930 - 16s - loss: 0.2595 - accuracy: 0.9069 - val_loss: 0.1961 - val_accuracy: 0.9453
# Epoch 2/100
# 930/930 - 16s - loss: 0.1524 - accuracy: 0.9617 - val_loss: 0.1697 - val_accuracy: 0.9530
# Epoch 3/100
# 930/930 - 16s - loss: 0.1259 - accuracy: 0.9713 - val_loss: 0.1653 - val_accuracy: 0.9534
# Epoch 4/100
# 930/930 - 15s - loss: 0.1091 - accuracy: 0.9780 - val_loss: 0.1659 - val_accuracy: 0.9547
# Epoch 5/100
# 930/930 - 16s - loss: 0.0998 - accuracy: 0.9815 - val_loss: 0.1711 - val_accuracy: 0.9568
# Epoch 6/100
# 930/930 - 15s - loss: 0.0923 - accuracy: 0.9840 - val_loss: 0.1625 - val_accuracy: 0.9561
# Epoch 7/100
# 930/930 - 15s - loss: 0.0874 - accuracy: 0.9851 - val_loss: 0.1611 - val_accuracy: 0.9547
# Epoch 8/100
# 930/930 - 15s - loss: 0.0813 - accuracy: 0.9878 - val_loss: 0.1600 - val_accuracy: 0.9584
# Epoch 9/100
# 930/930 - 16s - loss: 0.0781 - accuracy: 0.9886 - val_loss: 0.1560 - val_accuracy: 0.9591
# Epoch 10/100
# 930/930 - 15s - loss: 0.0749 - accuracy: 0.9890 - val_loss: 0.1549 - val_accuracy: 0.9611
# Epoch 11/100
# 930/930 - 15s - loss: 0.0713 - accuracy: 0.9904 - val_loss: 0.1590 - val_accuracy: 0.9588
# Epoch 12/100
# 930/930 - 15s - loss: 0.0685 - accuracy: 0.9916 - val_loss: 0.1526 - val_accuracy: 0.9554
# Epoch 13/100
# 930/930 - 15s - loss: 0.0674 - accuracy: 0.9915 - val_loss: 0.1578 - val_accuracy: 0.9584
# Epoch 14/100
# 930/930 - 15s - loss: 0.0650 - accuracy: 0.9922 - val_loss: 0.1562 - val_accuracy: 0.9571
# Epoch 15/100
# 930/930 - 15s - loss: 0.0632 - accuracy: 0.9924 - val_loss: 0.1375 - val_accuracy: 0.9649
# Epoch 16/100
# 930/930 - 15s - loss: 0.0614 - accuracy: 0.9928 - val_loss: 0.1522 - val_accuracy: 0.9608
# Epoch 17/100
# 930/930 - 15s - loss: 0.0610 - accuracy: 0.9926 - val_loss: 0.1441 - val_accuracy: 0.9601
# Epoch 18/100
# 930/930 - 15s - loss: 0.0590 - accuracy: 0.9933 - val_loss: 0.1298 - val_accuracy: 0.9628
# Epoch 19/100
# 930/930 - 15s - loss: 0.0579 - accuracy: 0.9933 - val_loss: 0.1588 - val_accuracy: 0.9601
# Epoch 20/100
# 930/930 - 15s - loss: 0.0575 - accuracy: 0.9938 - val_loss: 0.1632 - val_accuracy: 0.9601
# Epoch 1/100
# 930/930 - 44s - loss: 0.2466 - accuracy: 0.9304 - val_loss: 0.1846 - val_accuracy: 0.9639
# Epoch 2/100
# 930/930 - 45s - loss: 0.1540 - accuracy: 0.9715 - val_loss: 0.1752 - val_accuracy: 0.9635
# Epoch 3/100
# 930/930 - 45s - loss: 0.1322 - accuracy: 0.9793 - val_loss: 0.1697 - val_accuracy: 0.9595
# Epoch 4/100
# 930/930 - 45s - loss: 0.1182 - accuracy: 0.9834 - val_loss: 0.1740 - val_accuracy: 0.9591
# Epoch 5/100
# 930/930 - 46s - loss: 0.1090 - accuracy: 0.9870 - val_loss: 0.1684 - val_accuracy: 0.9649
# Epoch 6/100
# 930/930 - 44s - loss: 0.1033 - accuracy: 0.9878 - val_loss: 0.1638 - val_accuracy: 0.9598
# Epoch 7/100
# 930/930 - 42s - loss: 0.0975 - accuracy: 0.9885 - val_loss: 0.1447 - val_accuracy: 0.9747
# Epoch 8/100
# 930/930 - 42s - loss: 0.0939 - accuracy: 0.9894 - val_loss: 0.1546 - val_accuracy: 0.9655
# Epoch 9/100
# 930/930 - 43s - loss: 0.0885 - accuracy: 0.9911 - val_loss: 0.1583 - val_accuracy: 0.9689
# Epoch 10/100
# 930/930 - 43s - loss: 0.0871 - accuracy: 0.9909 - val_loss: 0.1579 - val_accuracy: 0.9622
# Epoch 11/100
# 930/930 - 42s - loss: 0.0805 - accuracy: 0.9926 - val_loss: 0.1596 - val_accuracy: 0.9639
# Epoch 12/100
# 930/930 - 43s - loss: 0.0805 - accuracy: 0.9923 - val_loss: 0.1459 - val_accuracy: 0.9706
# Epoch 1/100
# 930/930 - 15s - loss: 0.2383 - accuracy: 0.9039 - val_loss: 0.1757 - val_accuracy: 0.9453
# Epoch 2/100
# 930/930 - 16s - loss: 0.1281 - accuracy: 0.9564 - val_loss: 0.1357 - val_accuracy: 0.9480
# Epoch 3/100
# 930/930 - 16s - loss: 0.0916 - accuracy: 0.9690 - val_loss: 0.1300 - val_accuracy: 0.9507
# Epoch 4/100
# 930/930 - 16s - loss: 0.0733 - accuracy: 0.9752 - val_loss: 0.1270 - val_accuracy: 0.9551
# Epoch 5/100
# 930/930 - 17s - loss: 0.0604 - accuracy: 0.9800 - val_loss: 0.1440 - val_accuracy: 0.9517
# Epoch 6/100
# 930/930 - 17s - loss: 0.0514 - accuracy: 0.9836 - val_loss: 0.1308 - val_accuracy: 0.9598
# Epoch 7/100

# %%
EERs = np.load(results_path + 'osaka_filters_eers.npy')
# EERs[:,15:] = np.load('/content/drive/My Drive/icmla2020/results/osaka_eers3.npy')
print(EERs.shape)

# %%
means = np.mean(EERs, axis=1) * 100
print(means)

# %%
stds = np.std(EERs, axis=1) * 100
print(stds)

# %%
mins = np.min(EERs, axis=1) * 100
print(mins)

# %%
mins = np.max(EERs, axis=1) * 100
print(mins)
