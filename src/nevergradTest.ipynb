# %%
# !pip install nevergrad
# Out:
# Collecting nevergrad
#   Downloading https://files.pythonhosted.org/packages/71/f5/02910450d6df2a6c524c32973774c027fa5f5415d7a09d6f9a42c8ca4ccc/nevergrad-0.4.1.post5-py3-none-any.whl (279kB)
#      |████████████████████████████████| 286kB 5.4MB/s
# Collecting bayesian-optimization>=1.1.0
#   Downloading https://files.pythonhosted.org/packages/bb/7a/fd8059a3881d3ab37ac8f72f56b73937a14e8bb14a9733e68cc8b17dbe3c/bayesian-optimization-1.2.0.tar.gz
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from nevergrad) (1.18.5)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.6/dist-packages (from nevergrad) (3.7.4.2)
# Collecting cma>=2.6.0
#   Downloading https://files.pythonhosted.org/packages/36/c0/0a1c41f7cad0a51e07991cf86423d0e6651d035f1fe7dcff48e8858848f2/cma-3.0.3-py2.py3-none-any.whl (230kB)
#      |████████████████████████████████| 235kB 17.4MB/s
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.6/dist-packages (from bayesian-optimization>=1.1.0->nevergrad) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.18.0 in /usr/local/lib/python3.6/dist-packages (from bayesian-optimization>=1.1.0->nevergrad) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.18.0->bayesian-optimization>=1.1.0->nevergrad) (0.16.0)
# Building wheels for collected packages: bayesian-optimization
#   Building wheel for bayesian-optimization (setup.py) ... done
#   Created wheel for bayesian-optimization: filename=bayesian_optimization-1.2.0-cp36-none-any.whl size=11685 sha256=85203587b6536fda79f8f2483998841247c59f30f44f0c3f1981469c457a5df3
#   Stored in directory: /root/.cache/pip/wheels/5a/56/ae/e0e3c1fc1954dc3ec712e2df547235ed072b448094d8f94aec
# Successfully built bayesian-optimization
# Installing collected packages: bayesian-optimization, cma, nevergrad
# Successfully installed bayesian-optimization-1.2.0 cma-3.0.3 nevergrad-0.4.1.post5

# %%
import nevergrad as ng

# %%
def square(x, y=12):
    return sum((x - .5)**2) + abs(y)

# %%
inst = ng.p.Instrumentation(ng.p.Array(shape=(2,)), y=ng.p.Scalar())
optimizer = ng.optimizers.OnePlusOne(parametrization=inst, budget=100)
rec = optimizer.minimize(square)
print(rec.value)
# Out:
# ((array([0.68032496, 0.56656403]),), {'y': -0.0002486777549726215})

# %%
print('\n'.join(sorted(ng.optimizers.registry.keys())))
# Out:
# ASCMA2PDEthird
# ASCMADEQRthird
# ASCMADEthird
# AdaptiveDiscreteOnePlusOne
# AlmostRotationInvariantDE
# AvgMetaRecenteringNoHull
# BO
# CM
# CMA
# CMandAS
# CMandAS2
# CMandAS3
# CauchyLHSSearch
# CauchyOnePlusOne
# CauchyScrHammersleySearch
# Cobyla
# DE
# DiagonalCMA
# DiscreteBSOOnePlusOne
# DiscreteDoerrOnePlusOne
# DiscreteOnePlusOne
# DoubleFastGADiscreteOnePlusOne
# EDA
# ES
# FCMA
# HAvgMetaRecentering
# HaltonSearch
# HaltonSearchPlusMiddlePoint
# HammersleySearch
# HammersleySearchPlusMiddlePoint
# LHSSearch
# LargeHaltonSearch
# LhsDE
# MEDA
# MPCEDA
# ManyCMA
# ManySmallCMA
# MetaModel
# MetaRecentering
# MetaTuneRecentering
# MixES
# MultiCMA
# MultiDiscrete
# MultiScaleCMA
# MutDE
# NGO
# NGO10
# NaiveIsoEMNA
# NaiveTBPSA
# NelderMead
# NoisyBandit
# NoisyDE
# NoisyDiscreteOnePlusOne
# NoisyOnePlusOne
# ORandomSearch
# OScrHammersleySearch
# OnePlusOne
# OptimisticDiscreteOnePlusOne
# OptimisticNoisyOnePlusOne
# PCEDA
# PSO
# ParaPortfolio
# PolyCMA
# Portfolio
# Powell
# QORandomSearch
# QOScrHammersleySearch
# QrDE
# RCobyla
# RPowell
# RSQP
# RandomSearch
# RandomSearchPlusMiddlePoint
# RealSpacePSO
# RecES
# RecMixES
# RecMutDE
# RecombiningPortfolioOptimisticNoisyDiscreteOnePlusOne
# RotationInvariantDE
# SPSA
# SQP
# SQPCMA
# ScrHaltonSearch
# ScrHaltonSearchPlusMiddlePoint
# ScrHammersleySearch
# ScrHammersleySearchPlusMiddlePoint
# Shiwa
# SplitOptimizer
# TBPSA
# TripleCMA
# TwoPointsDE
# cGA
# chainCMAPowell

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
EERs = np.load('../results/ejust_filters_eers3.npy')
EERs[:,27:] = np.load('../results/ejust_filters_eers2.npy')[:,:3]
# print(EERs.shape, EERs)
means = np.mean(EERs, axis=1) * 100
print(means)

stds = np.std(EERs, axis=1) * 100
print(stds)

EERs[EERs == 0] = 1
mins = np.min(EERs, axis=1) * 100
print(mins)

EERs[EERs == 1] = 0
maxs = np.max(EERs, axis=1) * 100
print(mins)

table = pd.DataFrame(np.vstack([means, stds, mins, maxs]))
table.to_csv('../results/ejust_filters_eers_redone_csv.csv')
# Out:
# [15.8        15.79       16.22666667 14.27       14.31666667 15.67666667
#  13.95       15.84666667 13.48666667 12.61666667 13.49       15.31333333]
# [6.84197827 7.37881427 7.5825648  6.30614251 5.82386374 7.17805374
#  6.02421502 8.09340198 7.10491536 5.12881294 7.31898672 8.08767512]
# [4.1 3.4 3.4 3.2 5.6 3.  1.9 1.7 3.2 3.4 2.2 2.1]
# [4.1 3.4 3.4 3.2 5.6 3.  1.9 1.7 3.2 3.4 2.2 2.1]

# %%
EERs = np.load('../results/mmuisd_filters_eers.npy')
means = np.mean(EERs, axis=1) * 100
print(means)

stds = np.std(EERs, axis=1) * 100
print(stds)

EERs[EERs == 0] = 1
mins = np.min(EERs, axis=1) * 100
print(mins)

EERs[EERs == 1] = 0
maxs = np.max(EERs, axis=1) * 100
print(mins)

table = pd.DataFrame(np.vstack([means, stds, mins, maxs]))
table.to_csv('../results/mmuisd_filters_eers_csv.csv')
# Out:
# [9.21617162 9.96974697 7.05445545 7.95929593 8.80225523 9.67134213
#  6.2610011  7.279978   0.         0.         0.         0.        ]
# [3.1564232  2.7620622  2.71185346 2.86043015 2.74814583 2.80007208
#  2.82819388 2.64126797 0.         0.         0.         0.        ]
# [  2.84653465   4.8679868    1.73267327   1.11386139   3.71287129
#    4.16666667   0.99009901   3.01155116 100.         100.
#  100.         100.        ]
# [  2.84653465   4.8679868    1.73267327   1.11386139   3.71287129
#    4.16666667   0.99009901   3.01155116 100.         100.
#  100.         100.        ]

# %%
EERs = np.load('../results/osaka_filters_eers.npy')
EERs[:,:15] = np.load('../results/osaka_filters_eers2.npy')
means = np.mean(EERs, axis=1) * 100
print(means)

stds = np.std(EERs, axis=1) * 100
print(stds)

EERs[EERs == 0] = 1
mins = np.min(EERs, axis=1) * 100
print(mins)

EERs[EERs == 1] = 0
maxs = np.max(EERs, axis=1) * 100
print(mins)

table = pd.DataFrame(np.vstack([means, stds, mins, maxs]))
table.to_csv('../results/osaka_filters_eers_csv.csv')
# Out:
# [4.53333333 3.86666667 3.75555556 3.65777778 4.08888889 3.41777778
#  3.24444444 3.60444444 0.         0.         0.         0.        ]
# [0.75542483 0.7176092  0.6337036  0.66571784 0.80725109 0.60047718
#  0.59462614 0.73129684 0.         0.         0.         0.        ]
# [  3.33333333   2.66666667   2.66666667   2.53333333   2.93333333
#    2.46666667   2.06666667   2.53333333 100.         100.
#  100.         100.        ]
# [  3.33333333   2.66666667   2.66666667   2.53333333   2.93333333
#    2.46666667   2.06666667   2.53333333 100.         100.
#  100.         100.        ]

# %%
EERs = np.load('../results/huga_filters_eers.npy')
means = np.mean(EERs, axis=1) * 100
print(means)

stds = np.std(EERs, axis=1) * 100
print(stds)

EERs[EERs == 0] = 1
mins = np.min(EERs, axis=1) * 100
print(mins)

EERs[EERs == 1] = 0
maxs = np.max(EERs, axis=1) * 100
print(mins)

table = pd.DataFrame(np.vstack([means, stds, mins, maxs]))
table.to_csv('../results/huga_filters_eers_csv.csv')
# Out:
# [14.17333333 13.99       20.37333333 20.24666667 12.00666667 11.06
#  17.44333333 19.22333333 10.9        10.50666667 16.93666667 18.32666667]
# [7.66071943 7.91064051 6.09157524 5.84646522 7.16867879 6.38412615
#  7.10852462 7.87348645 5.7585299  6.28940555 7.05551715 7.82985455]
# [ 0.3  2.1  7.7 10.1  0.1  0.8  5.5  5.2  0.1  0.2  5.5  5.8]
# [ 0.3  2.1  7.7 10.1  0.1  0.8  5.5  5.2  0.1  0.2  5.5  5.8]

# %%
EERs = np.load('../results/TL_mat.npy')
print(EERs[:,:,0] * 100)
table = pd.DataFrame(EERs[:,:,0] * 100)
table.to_csv('../results/TL.csv')
# means = np.mean(EERs, axis=1) * 100
# print(means)

# stds = np.std(EERs, axis=1) * 100
# print(stds)

# EERs[EERs == 0] = 1
# mins = np.min(EERs, axis=1) * 100
# print(mins)

# EERs[EERs == 1] = 0
# maxs = np.max(EERs, axis=1) * 100
# print(mins)

# table = pd.DataFrame(np.vstack([means, stds, mins, maxs]))
# table.to_csv('../results/ejust_filters_eers_csv.csv')
# Out:
# [[ 0.         22.18918919 27.         13.45      ]
#  [18.9         0.         15.1        16.41666667]
#  [10.2        21.94594595  0.         11.33333333]
#  [13.7        15.94594595 29.9         0.        ]]

# %%
def build_model1(input_shape, bn, reg):
    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import Conv1D, \
                                        MaxPooling1D, \
                                        AveragePooling1D, \
                                        Dense, Flatten, Dropout, \
                                        BatchNormalization, \
                                        GlobalMaxPooling1D, \
                                        GlobalAveragePooling1D, \
                                        Activation
    from tensorflow.keras import activations
    import tensorflow.keras.regularizers as regularizers

    model = Sequential()
    if reg:
        model.add(Conv1D(16, 3, strides=1, input_shape=input_shape, 
                        kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4),
                        bias_regularizer=regularizers.l2(1e-4)))
    else:
        model.add(Conv1D(16, 3, strides=1, input_shape=input_shape))
    if bn:
        model.add(BatchNormalization())
    model.add(Activation(activations.relu))
    model.add(MaxPooling1D(pool_size=2))
    if reg:
        model.add(Conv1D(64, 5, strides=2, 
                        kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4),
                        bias_regularizer=regularizers.l2(1e-4)))
    else:
        model.add(Conv1D(64, 5, strides=2))
    if bn:
        model.add(BatchNormalization())
    model.add(Activation(activations.relu))
    model.add(AveragePooling1D(pool_size=2))
    model.add(GlobalMaxPooling1D())
    return model

def build_model2(input_shape, bn, reg):
    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import Conv1D, \
                                        MaxPooling1D, \
                                        AveragePooling1D, \
                                        Dense, Flatten, Dropout, \
                                        BatchNormalization, \
                                        GlobalMaxPooling1D, \
                                        GlobalAveragePooling1D, \
                                        Activation
    from tensorflow.keras import activations
    import tensorflow.keras.regularizers as regularizers

    model = Sequential()
    if reg:
        model.add(Conv1D(16, 3, strides=1, activation='tanh', input_shape=input_shape, kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4),bias_regularizer=regularizers.l2(1e-4)))
        model.add(Conv1D(32, 3, strides=2, activation='relu', kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4),bias_regularizer=regularizers.l2(1e-4)))
    else:
        model.add(Conv1D(16, 3, strides=1, activation='tanh', input_shape=input_shape))
        model.add(Conv1D(32, 3, strides=2, activation='relu'))
    
    if bn:
        model.add(BatchNormalization())

    model.add(MaxPooling1D(pool_size=2))

    if reg:
        model.add(Conv1D(64, 5, strides=2, activation='tanh', kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4),bias_regularizer=regularizers.l2(1e-4)))
        model.add(Conv1D(128, 5, strides=3, activation='relu', kernel_regularizer=regularizers.l1_l2(l1=1e-5, l2=1e-4),bias_regularizer=regularizers.l2(1e-4)))
    else:
        model.add(Conv1D(64, 5, strides=2, activation='tanh'))
        model.add(Conv1D(128, 5, strides=3, activation='relu'))
    
    if bn:
        model.add(BatchNormalization())

    model.add(GlobalMaxPooling1D())
    return model

def build_model3(input_shape, bn, reg):
    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import Conv1D, \
                                        MaxPooling1D, \
                                        AveragePooling1D, \
                                        Dense, Flatten, Dropout, \
                                        BatchNormalization, \
                                        GlobalMaxPooling1D, \
                                        GlobalAveragePooling1D, \
                                        Activation
    from tensorflow.keras import activations
    import tensorflow.keras.regularizers as regularizers

    model = Sequential()
    model.add(Conv1D(64, 5, strides=3, padding='valid', activation='relu', input_shape=input_shape))
    if bn: model.add(BatchNormalization())
    model.add(Conv1D(128, 3, strides=2, padding='valid', activation='relu'))
    model.add(MaxPooling1D(pool_size=2, strides=2))
    model.add(Conv1D(128, 2, strides=1, padding='valid', activation='tanh'))
    model.add(MaxPooling1D(pool_size=2, strides=2))
    model.add(GlobalMaxPooling1D())
    return model

# %%
import tensorflow.keras
m1 = build_model1((100, 6), 1, 1)
m2 = build_model2((100, 6), 1, 1)
m3 = build_model3((100, 6), 1, 1)
m1.summary()
m2.summary()
m3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 98, 16)            304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 98, 16)            64
# _________________________________________________________________
# activation (Activation)      (None, 98, 16)            0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 49, 16)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 23, 64)            5184
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 23, 64)            256
# _________________________________________________________________
# activation_1 (Activation)    (None, 23, 64)            0
# _________________________________________________________________
# average_pooling1d (AveragePo (None, 11, 64)            0
# _________________________________________________________________
# global_max_pooling1d (Global (None, 64)                0
# =================================================================
# Total params: 5,808
# Trainable params: 5,648
# Non-trainable params: 160
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_2 (Conv1D)            (None, 98, 16)            304
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 48, 32)            1568
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 48, 32)            128
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 24, 32)            0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 10, 64)            10304
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 2, 128)            41088
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 2, 128)            512
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 128)               0
# =================================================================
# Total params: 53,904
# Trainable params: 53,584
# Non-trainable params: 320
# _________________________________________________________________
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_6 (Conv1D)            (None, 32, 64)            1984
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 32, 64)            256
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 15, 128)           24704
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 7, 128)            0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 6, 128)            32896
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 3, 128)            0
# _________________________________________________________________
# global_max_pooling1d_2 (Glob (None, 128)               0
# =================================================================
# Total params: 59,840
# Trainable params: 59,712
# Non-trainable params: 128
# _________________________________________________________________

# %%
EERs = np.load('../results/huga_filters_eers.npy')

plt.boxplot(x=(EERs.T*100))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a4e3c13608>,
#   <matplotlib.lines.Line2D at 0x2a4e3c138c8>,
#   <matplotlib.lines.Line2D at 0x2a4e3c65e88>,
#   <matplotlib.lines.Line2D at 0x2a4e3c65f88>,
#   <matplotlib.lines.Line2D at 0x2a4e3c7b848>,
#   <matplotlib.lines.Line2D at 0x2a4e3c7be08>,
#   <matplotlib.lines.Line2D at 0x2a4e3c80ec8>,
#   <matplotlib.lines.Line2D at 0x2a4e3c883c8>,
#   <matplotlib.lines.Line2D at 0x2a4e3c9b748>,
#   <matplotlib.lines.Line2D at 0x2a4e3c7bcc8>,
#   <matplotlib.lines.Line2D at 0x2a4e3cab7c8>,
#   <matplotlib.lines.Line2D at 0x2a4e3ca47c8>,
#   <matplotlib.lines.Line2D at 0x2a4e3cbbd48>,
#   <matplotlib.lines.Line2D at 0x2a4e3cbb948>,
#   <matplotlib.lines.Line2D at 0x2a4e3cc9bc8>,
#   <matplotlib.lines.Line2D at 0x2a4e3cc9e88>,
#   <matplotlib.lines.Line2D at 0x2a4e3c94608>,
#   <matplotlib.lines.Line2D at 0x2a4e3cd9fc8>,
#   <matplotlib.lines.Line2D at 0x2a4e3cf1c88>,
#   <matplotlib.lines.Line2D at 0x2a4e3cf1888>,
#   <matplotlib.lines.Line2D at 0x2a4e3d00ac8>,
#   <matplotlib.lines.Line2D at 0x2a4e3d00d88>,
#   <matplotlib.lines.Line2D at 0x2a4e3d0fac8>,
#   <matplotlib.lines.Line2D at 0x2a4e3d0fec8>],
#  'caps': [<matplotlib.lines.Line2D at 0x2a4e3c13088>,
#   <matplotlib.lines.Line2D at 0x2a4e3c5d808>,
#   <matplotlib.lines.Line2D at 0x2a4e3c6b908>,
#   <matplotlib.lines.Line2D at 0x2a4e3c6bf08>,
#   <matplotlib.lines.Line2D at 0x2a4e3c7bf88>,
#   <matplotlib.lines.Line2D at 0x2a4e3c80a88>,
#   <matplotlib.lines.Line2D at 0x2a4e3c8e248>,
#   <matplotlib.lines.Line2D at 0x2a4e3c88f08>,
#   <matplotlib.lines.Line2D at 0x2a4e3c94248>,
#   <matplotlib.lines.Line2D at 0x2a4e3c80948>,
#   <matplotlib.lines.Line2D at 0x2a4e3cabfc8>,
#   <matplotlib.lines.Line2D at 0x2a4e3caba88>,
#   <matplotlib.lines.Line2D at 0x2a4e3cc32c8>,
#   <matplotlib.lines.Line2D at 0x2a4e3cbbfc8>,
#   <matplotlib.lines.Line2D at 0x2a4e3cd2808>,
#   <matplotlib.lines.Line2D at 0x2a4e3cd2fc8>,
#   <matplotlib.lines.Line2D at 0x2a4e3cdff48>,
#   <matplotlib.lines.Line2D at 0x2a4e3cdfa08>,
#   <matplotlib.lines.Line2D at 0x2a4e3cf91c8>,
#   <matplotlib.lines.Line2D at 0x2a4e3cf1ec8>,
#   <matplotlib.lines.Line2D at 0x2a4e3d07708>,
#   <matplotlib.lines.Line2D at 0x2a4e3d07ec8>,
#   <matplotlib.lines.Line2D at 0x2a4e3d18ec8>,
#   <matplotlib.lines.Line2D at 0x2a4e3d18948>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2a4e3c0f488>,
#   <matplotlib.lines.Line2D at 0x2a4e3c65908>,
#   <matplotlib.lines.Line2D at 0x2a4e3c653c8>,
#   <matplotlib.lines.Line2D at 0x2a4e3c74c08>,
#   <matplotlib.lines.Line2D at 0x2a4e3c94c88>,
#   <matplotlib.lines.Line2D at 0x2a4e3c94d48>,
#   <matplotlib.lines.Line2D at 0x2a4e3cab348>,
#   <matplotlib.lines.Line2D at 0x2a4e3cbb888>,
#   <matplotlib.lines.Line2D at 0x2a4e3c88808>,
#   <matplotlib.lines.Line2D at 0x2a4e3ca4f48>,
#   <matplotlib.lines.Line2D at 0x2a4e3cf1848>,
#   <matplotlib.lines.Line2D at 0x2a4e3d00cc8>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a4e3c5dd88>,
#   <matplotlib.lines.Line2D at 0x2a4e3c6be88>,
#   <matplotlib.lines.Line2D at 0x2a4e3c80f88>,
#   <matplotlib.lines.Line2D at 0x2a4e3c8ef48>,
#   <matplotlib.lines.Line2D at 0x2a4e3c9ba88>,
#   <matplotlib.lines.Line2D at 0x2a4e3cb22c8>,
#   <matplotlib.lines.Line2D at 0x2a4e3cc3fc8>,
#   <matplotlib.lines.Line2D at 0x2a4e3cd2d48>,
#   <matplotlib.lines.Line2D at 0x2a4e3ce9248>,
#   <matplotlib.lines.Line2D at 0x2a4e3cf9ec8>,
#   <matplotlib.lines.Line2D at 0x2a4e3d07c48>,
#   <matplotlib.lines.Line2D at 0x2a4e3d1e1c8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a4e3c5de88>,
#   <matplotlib.lines.Line2D at 0x2a4e3c74b48>,
#   <matplotlib.lines.Line2D at 0x2a4e3c88748>,
#   <matplotlib.lines.Line2D at 0x2a4e3c8ecc8>,
#   <matplotlib.lines.Line2D at 0x2a4e3ca4dc8>,
#   <matplotlib.lines.Line2D at 0x2a4e3cb2fc8>,
#   <matplotlib.lines.Line2D at 0x2a4e3cc3d48>,
#   <matplotlib.lines.Line2D at 0x2a4e3cd92c8>,
#   <matplotlib.lines.Line2D at 0x2a4e3ca4a08>,
#   <matplotlib.lines.Line2D at 0x2a4e3cf9c48>,
#   <matplotlib.lines.Line2D at 0x2a4e3d0f1c8>,
#   <matplotlib.lines.Line2D at 0x2a4e3d1eec8>],
#  'means': []}

# %%
EERs = np.load('../results/osaka_filters_eers.npy')
EERs[:,:15] = np.load('../results/osaka_filters_eers2.npy')

plt.boxplot(x=(EERs.T*100))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a4e3db4f88>,
#   <matplotlib.lines.Line2D at 0x2a4e3db4f08>,
#   <matplotlib.lines.Line2D at 0x2a4e3dc56c8>,
#   <matplotlib.lines.Line2D at 0x2a4e3dbd408>,
#   <matplotlib.lines.Line2D at 0x2a4e3dd3c88>,
#   <matplotlib.lines.Line2D at 0x2a4e3dd3c08>,
#   <matplotlib.lines.Line2D at 0x2a4e3de0388>,
#   <matplotlib.lines.Line2D at 0x2a4e3de0988>,
#   <matplotlib.lines.Line2D at 0x2a4e3df7b88>,
#   <matplotlib.lines.Line2D at 0x2a4e3dd3d88>,
#   <matplotlib.lines.Line2D at 0x2a4e3dfdf88>,
#   <matplotlib.lines.Line2D at 0x2a4e3e053c8>,
#   <matplotlib.lines.Line2D at 0x2a4e3e14588>,
#   <matplotlib.lines.Line2D at 0x2a4e3e14988>,
#   <matplotlib.lines.Line2D at 0x2a4e3e23ac8>,
#   <matplotlib.lines.Line2D at 0x2a4e3e2cc48>,
#   <matplotlib.lines.Line2D at 0x2a4e3df1a48>,
#   <matplotlib.lines.Line2D at 0x2a4e3e3a448>,
#   <matplotlib.lines.Line2D at 0x2a4e3e4a508>,
#   <matplotlib.lines.Line2D at 0x2a4e3e4a908>,
#   <matplotlib.lines.Line2D at 0x2a4e3e5a9c8>,
#   <matplotlib.lines.Line2D at 0x2a4e3e5adc8>,
#   <matplotlib.lines.Line2D at 0x2a4e3e70288>,
#   <matplotlib.lines.Line2D at 0x2a4e3e70708>],
#  'caps': [<matplotlib.lines.Line2D at 0x2a4e3d89ac8>,
#   <matplotlib.lines.Line2D at 0x2a4e3d89fc8>,
#   <matplotlib.lines.Line2D at 0x2a4e3dc5d08>,
#   <matplotlib.lines.Line2D at 0x2a4e3dcc6c8>,
#   <matplotlib.lines.Line2D at 0x2a4e3dd9948>,
#   <matplotlib.lines.Line2D at 0x2a4e3dd9f08>,
#   <matplotlib.lines.Line2D at 0x2a4e3de0508>,
#   <matplotlib.lines.Line2D at 0x2a4e3de8e48>,
#   <matplotlib.lines.Line2D at 0x2a4e3df7ec8>,
#   <matplotlib.lines.Line2D at 0x2a4e3dd9dc8>,
#   <matplotlib.lines.Line2D at 0x2a4e3e0d1c8>,
#   <matplotlib.lines.Line2D at 0x2a4e3e05e88>,
#   <matplotlib.lines.Line2D at 0x2a4e3e1b708>,
#   <matplotlib.lines.Line2D at 0x2a4e3e1bec8>,
#   <matplotlib.lines.Line2D at 0x2a4e3e23708>,
#   <matplotlib.lines.Line2D at 0x2a4e3e331c8>,
#   <matplotlib.lines.Line2D at 0x2a4e3e41188>,
#   <matplotlib.lines.Line2D at 0x2a4e3e3ae48>,
#   <matplotlib.lines.Line2D at 0x2a4e3e52608>,
#   <matplotlib.lines.Line2D at 0x2a4e3e52308>,
#   <matplotlib.lines.Line2D at 0x2a4e3e60b48>,
#   <matplotlib.lines.Line2D at 0x2a4e3e60848>,
#   <matplotlib.lines.Line2D at 0x2a4e3e73dc8>,
#   <matplotlib.lines.Line2D at 0x2a4e3e73608>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2a4e3db4808>,
#   <matplotlib.lines.Line2D at 0x2a4e3dbdfc8>,
#   <matplotlib.lines.Line2D at 0x2a4e3dbdbc8>,
#   <matplotlib.lines.Line2D at 0x2a4e3dd3248>,
#   <matplotlib.lines.Line2D at 0x2a4e3df7108>,
#   <matplotlib.lines.Line2D at 0x2a4e3e05648>,
#   <matplotlib.lines.Line2D at 0x2a4e3e05788>,
#   <matplotlib.lines.Line2D at 0x2a4e3e14cc8>,
#   <matplotlib.lines.Line2D at 0x2a4e3de0c88>,
#   <matplotlib.lines.Line2D at 0x2a4e3df71c8>,
#   <matplotlib.lines.Line2D at 0x2a4e3e5ac48>,
#   <matplotlib.lines.Line2D at 0x2a4e3e60148>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a4e3d89f88>,
#   <matplotlib.lines.Line2D at 0x2a4e3dccc08>,
#   <matplotlib.lines.Line2D at 0x2a4e3dd9ec8>,
#   <matplotlib.lines.Line2D at 0x2a4e3de8908>,
#   <matplotlib.lines.Line2D at 0x2a4e3dfd1c8>,
#   <matplotlib.lines.Line2D at 0x2a4e3e0dec8>,
#   <matplotlib.lines.Line2D at 0x2a4e3e1bc48>,
#   <matplotlib.lines.Line2D at 0x2a4e3e2cec8>,
#   <matplotlib.lines.Line2D at 0x2a4e3e41e48>,
#   <matplotlib.lines.Line2D at 0x2a4e3e52b48>,
#   <matplotlib.lines.Line2D at 0x2a4e3e670c8>,
#   <matplotlib.lines.Line2D at 0x2a4e3e7ad08>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a4e3dbdb08>,
#   <matplotlib.lines.Line2D at 0x2a4e3dccd08>,
#   <matplotlib.lines.Line2D at 0x2a4e3de0bc8>,
#   <matplotlib.lines.Line2D at 0x2a4e3df1148>,
#   <matplotlib.lines.Line2D at 0x2a4e3dfd6c8>,
#   <matplotlib.lines.Line2D at 0x2a4e3e0dc48>,
#   <matplotlib.lines.Line2D at 0x2a4e3e231c8>,
#   <matplotlib.lines.Line2D at 0x2a4e3e33ec8>,
#   <matplotlib.lines.Line2D at 0x2a4e3dfde48>,
#   <matplotlib.lines.Line2D at 0x2a4e3e5a0c8>,
#   <matplotlib.lines.Line2D at 0x2a4e3e67f48>,
#   <matplotlib.lines.Line2D at 0x2a4e3e7aa48>],
#  'means': []}
